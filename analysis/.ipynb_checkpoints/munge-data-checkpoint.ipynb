# %%
import pandas as pd
import re

# %%
f_raw = '../static/data/death-and-co-raw-data.csv'
all_columns = ['row', 'page', 'name', 'ingredient', 'simple_ingredient', 'quantity', 'notes', 'empty', 'empty2']
drop_columns = ['row', 'page', 'notes', 'empty', 'empty2']

# %%
# Read file and drop unneeded columns
df_raw = pd.read_csv(f_raw)
df_raw.columns = all_columns
df_raw = df_raw.drop(drop_columns, 'columns')

# %%
df_raw.head()
# Out:
#    row   page          name                          ingredient  \
# 0    2    NaN           NaN                                 NaN
# 1    3  139.0  20TH CENTURY            BEEFEATER LONDON DRY GIN
# 2    4  139.0  20TH CENTURY  MARIE BRIZARD WHITE CRÈME DE CACAO
# 3    5  139.0  20TH CENTURY                    COCCHI AMERICANO
# 4    6  139.0  20TH CENTURY                         LEMON JUICE
#
#              simple_ingredient quantity  \
# 0                          NaN      NaN
# 1             GIN (LONDON DRY)      1.5
# 2     LIQUEUR (CRÈME DE CACAO)     0.75
# 3  APERITIF (COCCHI AMERICANO)     0.75
# 4                JUICE (LEMON)     0.75
#
#                                              notes empty empty2
# 0                                              NaN   NaN    NaN
# 1  Shake all the ingredients with ice, then double   NaN    NaN
# 2                 strain into a coupe. No garnish.   NaN    NaN
# 3                                              NaN   NaN    NaN
# 4                                              NaN   NaN    NaN

# %%
# Copy and drop null rows (these separate cocktails in raw csv)
df = df_raw.copy()
df = df.dropna(how='all')

# %%
df.head()
# Out:
#            name                          ingredient  \
# 1  20TH CENTURY            BEEFEATER LONDON DRY GIN
# 2  20TH CENTURY  MARIE BRIZARD WHITE CRÈME DE CACAO
# 3  20TH CENTURY                    COCCHI AMERICANO
# 4  20TH CENTURY                         LEMON JUICE
# 6       AIRMAIL        RON DEL BARRILITO 3-STAR RUM
#
#              simple_ingredient quantity
# 1             GIN (LONDON DRY)      1.5
# 2     LIQUEUR (CRÈME DE CACAO)     0.75
# 3  APERITIF (COCCHI AMERICANO)     0.75
# 4                JUICE (LEMON)     0.75
# 6                RUM (SPANISH)        1

# %%
grouped_cocktails = df.groupby('name')

# %%
# matches 'SIMPLE SIMPLE (SPECIFIC (MORE SPECIFIC))' as 2 groups
name_regex = '([^\(\)]*)\((.*)\)'

cocktails = {}
ingredients = set()
simple_ingredients = set()
verbose_ingredients = set()

for cocktail in grouped_cocktails.groups:
    group = grouped_cocktails.get_group(cocktail)
    
    cocktail_ingredients = {}
    
    for i, item in group.iterrows():
        verbose_ingredient = item[1]
        ingredient = item[2]
        
        if pd.isna(ingredient): 
            continue

        ingredient_match = re.match(name_regex, ingredient)
        simple_ingredient = ingredient_match.group(1) if ingredient_match else ingredient
        simple_ingredient = simple_ingredient.strip()
        
        ingredient_obj = { 
            'cocktail': cocktail,
            'ingredient': ingredient,
            'simple_ingredient': simple_ingredient, 
            'verbose_ingredient': verbose_ingredient, 
            'quantity': item[3],
        }
        
        # key on most specific ingredient
        cocktail_ingredients[ingredient_verbose] = ingredient_obj
        
        ingredients.add(ingredient)
        simple_ingredients.add(simple_ingredient)
        verbose_ingredients.add(verbose_ingredient)
        
        
    cocktails[cocktail] = cocktail_ingredients

# %%
print(len(simple_ingredients), len(ingredients),len(verbose_ingredients), len(cocktails))
# Out:
# 46 222 451 486

# %%
simple_ingredients
# Out:
# {'ABSINTHE',
#  'AGAVE',
#  'AMARO',
#  'APERITIF',
#  'APPERITIF',
#  'APÉRITIF',
#  'AU CHOIX',
#  'BATAVIA ARRACK',
#  'BEER',
#  'BITTERS',
#  'BRANDY',
#  'BUTTER',
#  'CACHAÇA',
#  'CHARTREUSE',
#  'CHERRY HEERING',
#  'CIDER',
#  'CORDIAL',
#  'CREAM',
#  'EGG',
#  'FRUIT',
#  'GIN',
#  'JUICE',
#  'LEAF',
#  'LIQUEUR',
#  'MADEIRA',
#  'MINT',
#  'MIX',
#  'OTHER',
#  'PUREE',
#  'RIM',
#  'RUM',
#  'SALT',
#  'SHERRY',
#  'SHRUB',
#  'SODA',
#  'SPICE',
#  'SUGAR',
#  'SUGAR CUBE',
#  'SYRUP',
#  'TWIST',
#  'VEGETABLE',
#  'VERMOUTH',
#  'VODKA',
#  'WATER',
#  'WHISKEY',
#  'WINE'}

# %%
ingredients
# Out:
# {'ABSINTHE',
#  'AGAVE (MEZCAL)',
#  'AGAVE (TEQUILA ANEJO)',
#  'AGAVE (TEQUILA BLANCO)',
#  'AGAVE (TEQUILA REPOSADO)',
#  'AMARO (APERITIVO)',
#  'AMARO (CYNAR)',
#  'AMARO (FERNET)',
#  'AMARO (MEDIUM)',
#  'AMARO (MILD)',
#  'APERITIF (COCCHI AMERICANO)',
#  'APERITIF (GENTIANE-QUINA)',
#  'APERITIF (RASPBERRY)',
#  'APERITIF (SALERS GENTIAN)',
#  'APPERITIF (LILLET BLANC)',
#  'APPERITIF (LILLET ROSÉ)',
#  'APPERITIF (LILLET ROUGE)',
#  'APÉRITIF (???)',
#  'AU CHOIX',
#  'BATAVIA ARRACK',
#  'BEER (DOUBLE/IMPERIAL IPA)',
#  'BEER (SCHWARZBIER/DUNKEL)',
#  'BEER (SWEET/MILK STOUT)',
#  'BEER (VIENNA LAGER)',
#  'BEER (WITBIER)',
#  'BITTERS (ALLSPICE)',
#  'BITTERS (APPLE)',
#  'BITTERS (AROMATIC)',
#  'BITTERS (BECHEROVKA)',
#  'BITTERS (CELERY)',
#  'BITTERS (CHERRY BARK AND VANILLA)',
#  'BITTERS (CHOCOLATE)',
#  'BITTERS (CREOLE)',
#  'BITTERS (GRAPEFRUIT)',
#  'BITTERS (LAVENDER)',
#  'BITTERS (ORANGE)',
#  'BITTERS (TIKI)',
#  'BRANDY (APPLE)',
#  'BRANDY (CHERRY)',
#  'BRANDY (GRAPE)',
#  'BRANDY (PEAR)',
#  'BRANDY (PISCO)',
#  'BUTTER (APPLE)',
#  'BUTTER (PUMPKIN)',
#  'CACHAÇA',
#  'CHARTREUSE (GREEN)',
#  'CHARTREUSE (YELLOW)',
#  'CHERRY HEERING',
#  'CIDER (APPLE)',
#  'CIDER (PEAR)',
#  'CORDIAL (BLACK CURRANT)',
#  'CORDIAL (KUMQUAT)',
#  'CORDIAL (LIME)',
#  'CREAM (COCONUT)',
#  'CREAM (HEAVY)',
#  'EGG',
#  'EGG (WHITE)',
#  'EGG (WHOLE)',
#  'EGG (YOLK)',
#  'FRUIT (APPLE)',
#  'FRUIT (BLACKBERRY)',
#  'FRUIT (CHERRY)',
#  'FRUIT (GRAPE)',
#  'FRUIT (LIME)',
#  'FRUIT (NECTARINE)',
#  'FRUIT (ORANGE)',
#  'FRUIT (PEACH)',
#  'FRUIT (PEAR)',
#  'FRUIT (RASPBERRY)',
#  'FRUIT (STRAWBERRY)',
#  'FRUIT (TANGERINE)',
#  'FRUIT (TOMATO)',
#  'GIN',
#  'GIN (AMERICAN)',
#  'GIN (GENEVER)',
#  'GIN (LONDON DRY)',
#  'GIN (OLD TOM)',
#  'GIN (PLYMOUTH)',
#  'GIN (SLOE)',
#  'JUICE (APPLE)',
#  'JUICE (BLOOD ORANGE)',
#  'JUICE (CANTALOUPE)',
#  'JUICE (CELERY)',
#  'JUICE (GRAPEFRUIT)',
#  'JUICE (LEMON)',
#  'JUICE (LIME)',
#  'JUICE (ORANGE)',
#  'JUICE (PINEAPPLE)',
#  'JUICE (WATERMELON)',
#  'LEAF (BASIL)',
#  'LEAF (CURRY)',
#  'LEAF (KAFFIR LIME)',
#  'LEAF (SAGE)',
#  'LIQUEUR',
#  'LIQUEUR (ALLSPICE DRAM)',
#  'LIQUEUR (ALMOND)',
#  'LIQUEUR (APRICOT)',
#  'LIQUEUR (BLACKBERRY)',
#  'LIQUEUR (BLOOD ORANGE)',
#  'LIQUEUR (BÉNÉDICTINE)',
#  'LIQUEUR (CARAWAY)',
#  'LIQUEUR (CARAWAY) (AQUAVIT)',
#  'LIQUEUR (CHERRY)',
#  'LIQUEUR (COCONUT)',
#  'LIQUEUR (CRÈME DE CACAO)',
#  'LIQUEUR (CRÈME DE CASSIS)',
#  'LIQUEUR (CRÈME DE MENTHE)',
#  'LIQUEUR (CRÈME DE VIOLETTE)',
#  'LIQUEUR (CRÈME YVETTE)',
#  'LIQUEUR (DRAMBUIE)',
#  'LIQUEUR (ELDERFLOWER)',
#  'LIQUEUR (FALERNUM)',
#  'LIQUEUR (GALLIANO)',
#  'LIQUEUR (GRAPEFRUIT)',
#  'LIQUEUR (ORANGE)',
#  'LIQUEUR (PEACH)',
#  'LIQUEUR (PEAR)',
#  'LIQUEUR (PINE)',
#  'LIQUEUR (ROSE)',
#  'LIQUEUR (STRAWBERRY)',
#  'LIQUEUR (STREGA)',
#  'LIQUEUR (SUZE)',
#  'LIQUEUR (SWEDISH PUNSCH)',
#  'MADEIRA',
#  'MINT',
#  'MIX (BERGERAC MIX)',
#  'MIX (DONN’S MIX #1)',
#  'MIX (DONN’S SPICES #2)',
#  'MIX (PENDENNIS MIX)',
#  'MIX (ZOMBIE MIX)',
#  'OTHER (ACID PHOSPHATE)',
#  'OTHER (BECHEROVKA)',
#  'OTHER (CILANTRO)',
#  'OTHER (HORCHATA)',
#  'OTHER (HOT SAUCE)',
#  'OTHER (KIRSCH)',
#  'OTHER (LEMON CURD)',
#  'OTHER (MARMALADE (ORANGE))',
#  'OTHER (ORANGE FLOWER WATER)',
#  'OTHER (POMEGRANATE MOLASSES)',
#  'OTHER (ROSE WATER)',
#  'OTHER (VERJUS)',
#  'OTHER (VINEGAR)',
#  'OTHER (YOGURT)',
#  'PUREE (KALAMANSI)',
#  'PUREE (PUMPKIN)',
#  'RIM (CINNAMON SUGAR)',
#  'RIM (SPICY SUGAR AND SALT)',
#  'RIM (TOASTED FENNEL SALT)',
#  'RUM (AGRICOLE AMBRE)',
#  'RUM (AGRICOLE BLANC)',
#  'RUM (DEMERARA OVERPROOF)',
#  'RUM (DEMERARA WHITE)',
#  'RUM (DEMERARA)',
#  'RUM (ENGLISH WHITE)',
#  'RUM (ENGLISH)',
#  'RUM (JAMAICAN WHITE)',
#  'RUM (JAMAICAN)',
#  'RUM (SPANISH WHITE)',
#  'RUM (SPANISH)',
#  'SALT',
#  'SHERRY',
#  'SHERRY (AMONTILLADO)',
#  'SHERRY (CREAM)',
#  'SHERRY (MANZANILLA)',
#  'SHERRY (OLOROSO)',
#  'SHERRY (PALE CREAM)',
#  'SHRUB (HABANERO)',
#  'SHRUB (SOUR CHERRY)',
#  'SODA',
#  'SODA (GRAPEFRUIT)',
#  'SPICE (CARDAMOM PODS)',
#  'SPICE (CINNAMON)',
#  'SPICE (NUTMEG)',
#  'SUGAR',
#  'SUGAR CUBE',
#  'SYRUP (AGAVE NECTAR)',
#  'SYRUP (AGAVE)',
#  'SYRUP (APPLE)',
#  'SYRUP (BANANA)',
#  'SYRUP (BLUEBERRY)',
#  'SYRUP (CANE SUGAR)',
#  'SYRUP (CINNAMON)',
#  'SYRUP (CUMIN)',
#  'SYRUP (DEMERARA)',
#  'SYRUP (GASTRIQUE)',
#  'SYRUP (GINGER)',
#  'SYRUP (GRENADINE)',
#  'SYRUP (HIBISCUS)',
#  'SYRUP (HONEY)',
#  'SYRUP (MAPLE)',
#  'SYRUP (ORGEAT)',
#  'SYRUP (PASSION FRUIT)',
#  'SYRUP (SCARLET GLOW TEA)',
#  'SYRUP (SIMPLE)',
#  'SYRUP (VANILLA)',
#  'TWIST (GRAPEFRUIT)',
#  'TWIST (LEMON)',
#  'TWIST (ORANGE)',
#  'VEGETABLE (CUCUMBER)',
#  'VERMOUTH (BLANC)',
#  'VERMOUTH (DRY)',
#  'VERMOUTH (SWEET)',
#  'VODKA',
#  'VODKA (CHOCOLATE)',
#  'WATER (COCONUT)',
#  'WHISKEY (BOURBON)',
#  'WHISKEY (IRISH)',
#  'WHISKEY (JAPANESE)',
#  'WHISKEY (OAT)',
#  'WHISKEY (RYE)',
#  'WHISKEY (SCOTCH BLENDED)',
#  'WHISKEY (SCOTCH CAMPBELTOWN)',
#  'WHISKEY (SCOTCH HIGHLANDS)',
#  'WHISKEY (SCOTCH ISLAY)',
#  'WHISKEY (SCOTCH SPEYSIDE)',
#  'WHISKEY (WHEAT)',
#  'WINE (PORT)',
#  'WINE (RED)',
#  'WINE (SPARKLING ROSÉ)',
#  'WINE (SPARKLING)',
#  'WINE (WHITE)'}

# %%
verbose_ingredients
# Out:
# {'ABBOTT’S BITTERS',
#  'ACACIA HONEY SYRUP',
#  'ACID PHOSPHATE',
#  'AGAVE NECTAR',
#  'AGAVE SYRUP',
#  'AGED BALSAMIC VINEGAR',
#  'ALCHEMIA CHOCOLATE VODKA',
#  'ALVEAR FESTIVAL PALE CREAM SHERRY',
#  'AMARETTO',
#  'AMARO AVERNA',
#  'AMARO CIOCIARO',
#  'AMARO LUCANO',
#  'AMARO MELETTI',
#  'AMARO NARDINI',
#  'AMARO NONINO',
#  'AMERICAN FRUITS BLACK CURRANT CORDIAL',
#  'ANCHO CHILE-INFUSED DOLIN ROUGE VERMOUTH',
#  'ANCHO CHILE–INFUSED DOLIN ROUGE VERMOUTH',
#  'ANCHOR GENEVIEVE GIN',
#  'ANCHOR JUNIPERO GIN',
#  'ANGOSTURA 5-YEAR RUM',
#  'ANGOSTURA BITTERS',
#  'ANGOSTURA ORANGE BITTERS',
#  'APEROL',
#  'APPLE BUTTER',
#  'APPLE JUICE',
#  'APPLETON ESTATE RESERVE RUM',
#  'APPLETON ESTATE V/X RUM',
#  'APPLETON WHITE RUM',
#  'APRICOT-INFUSED FAMOUS GROUSE SCOTCH',
#  'AVIATION GIN',
#  'AVUÁ AMBURANA CACHAÇA',
#  'BACARDI RON SUPERIOR LIMITED EDITION',
#  'BAKER’S BOURBON',
#  'BANANA CHIP–INFUSED GOSLING’S BLACK SEAL RUM',
#  'BANANA SYRUP',
#  'BANKS 5-ISLAND WHITE RUM',
#  'BAR CODE BAKED APPLE BITTERS',
#  'BARBADILLO PRINCIPE AMONTILLADO SHERRY',
#  'BARBANCOURT 3-STAR RUM',
#  'BARBANCOURT WHITE RUM',
#  'BARTLETT PEAR CUBED',
#  'BASIL-INFUSED DOLIN BLANC VERMOUTH',
#  'BECHEROVKA',
#  'BECHEROVKA BITTERS',
#  'BEEFEATER 24 GIN',
#  'BEEFEATER LONDON DRY GIN',
#  'BEEFEATER LONDON DRY GIN APPLETON ESTATE V/X RUM SIEMBRA AZUL BLANCO TEQUILA COMPASS BOX ASYLA SCOTCH CALVADOS OR HINE H COGNAC',
#  'BERGERAC MIX',
#  'BERNHEIM WHEAT WHISKEY',
#  'BITTER TRUTH AROMATIC BITTERS',
#  'BITTER TRUTH CELERY BITTERS',
#  'BITTER TRUTH JERRY THOMAS’ BITTERS',
#  'BITTERCUBE CHERRY BARK AND VANILLA BITTERS',
#  'BITTERMENS HELLFIRE HABANERO SHRUB',
#  'BITTERMENS HOPPED GRAPEFRUIT BITTERS',
#  'BITTERMENS XOCOLATL MOLE BITTERS',
#  'BITTERMENS ‘ELEMAKULE TIKI BITTERS',
#  'BITTERMENS ’ELEMAKULE TIKI BITTERS',
#  'BLACKBERRIES',
#  'BLANCHE DE BRUXELLES BEER',
#  'BLANDY’S 5-YEAR MALMSEY MADEIRA',
#  'BLOOD ORANGE JUICE',
#  'BLUEBERRY SYRUP',
#  'BOIRON KALAMANSI PUREE',
#  'BOLS BARREL-AGED GENEVER',
#  'BOLS GENEVER',
#  'BOMBAY LONDON DRY GIN',
#  'BONAL GENTIANE-QUINA',
#  'BOWMORE 12-YEAR SCOTCH',
#  'BRAEBURN APPLE SYRUP',
#  'BRANDIED CHERRIES',
#  'BRUICHLADDICH BOTANIST GIN',
#  'BRUICHLADDICH PORT CHARLOTTE 7-YEAR SCOTCH',
#  'BUFFALO TRACE BOURBON',
#  'BULLEIT BOURBON',
#  'BUSHMILLS IRISH WHISKEY',
#  'BUSNEL VSOP CALVADOS',
#  'BÉNÉDICTINE',
#  'CABEZA BLANCO TEQUILA',
#  'CABRITO BLANCO TEQUILA',
#  'CACAO NIB–INFUSED CABEZA BLANCO TEQUILA',
#  'CACAO NIB–INFUSED CAMPARI',
#  'CALVADOS',
#  'CAMPARI',
#  'CAMPO DE ENCANTO ACHOLADO PISCO',
#  'CANE SUGAR SYRUP',
#  'CANTALOUPE JUICE',
#  'CAOL ILA 12-YEAR SCOTCH',
#  'CARDAMARO',
#  'CARDAMOM PODS',
#  'CARPANO ANTICA FORMULA VERMOUTH',
#  'CAÑA BRAVA RUM',
#  'CELERY JUICE',
#  'CENTINELA REPOSADO TEQUILA',
#  'CHAMOMILE-INFUSED BIANCO VERMOUTH',
#  'CHAMOMILE-INFUSED OLD OVERHOLT RYE',
#  'CHARBAY VODKA',
#  'CHERRY HEERING',
#  'CHERRY TOMATO',
#  'CHINACO VERDE BLANCO TEQUILA',
#  'CILANTRO SPRIG',
#  'CINNAMON BARK SYRUP',
#  'CINNAMON ORANGE TEA–INFUSED SWEET VERMOUTH',
#  'CINNAMON STICK',
#  'CINNAMON-SUGAR RIM',
#  'CLEAR CREEK APPLE BRANDY',
#  'CLEAR CREEK PEAR BRANDY',
#  'CLONTARF 1014 IRISH WHISKEY',
#  'CLUB SODA',
#  'COCCHI AMERICANO',
#  'COCCHI AMERICANO ROSA',
#  'COCCHI VERMOUTH DI TORINO',
#  'COCO LOPEZ',
#  'COCONUT GREEN TEA–INFUSED FAMOUS GROUSE SCOTCH',
#  'COCONUT WATER',
#  'COFFEE- AND CHILE-INFUSED CAMPARI',
#  'COFFEE-INFUSED CARPANO ANTICA FORMULA VERMOUTH',
#  'COGNAC',
#  'COINTREAU',
#  'COMBIER PAMPLEMOUSSE ROSE LIQUEUR',
#  'COMPASS BOX ASYLA SCOTCH',
#  'CONTRATTA VERMOUTH BIANCO',
#  'CONTRATTO AMERICANO ROSSO VERMOUTH',
#  'COURVOISIER COGNAC',
#  'CRUZAN BLACK STRAP RUM',
#  'CRUZAN SINGLE-BARREL RUM',
#  'CRÈME DE CASSIS',
#  'CRÈME YVETTE',
#  'CRÈME YVETTE PLUS MORE FOR TOPPING THE DRINK',
#  'CUCUMBER WHEELS',
#  'CUMIN SYRUP',
#  'CURRIED GINGER SYRUP',
#  'CYNAR',
#  'DALE DEGROFF’S PIMENTO BITTERS',
#  'DEL MAGUEY CHICHICAPA MEZCAL',
#  'DEL MAGUEY CREMA DE MEZCAL',
#  'DEL MAGUEY ESPADIN ESPECIAL MEZCAL',
#  'DEL MAGUEY SAN LUIS DEL RIO MEZCAL',
#  'DEL MAGUEY VIDA MEZCAL',
#  'DEMERARA SUGAR CUBES',
#  'DEMERARA SYRUP',
#  'DIPLOMÁTICO RESERVA EXCLUSIVA RUM',
#  'DOC’S HARD APPLE CIDER',
#  'DOC’S HARD PEAR CIDER',
#  'DOLIN BLANC VERMOUTH',
#  'DOLIN DRY VERMOUTH',
#  'DOLIN GÉNÉPY DES ALPES LIQUEUR',
#  'DOLIN ROUGE VERMOUTH',
#  'DON JULIO BLANCO TEQUILA',
#  'DONN’S MIX #1',
#  'DONN’S SPICES #2',
#  'DOROTHY PARKER GIN',
#  'DRAMBUIE',
#  'DRIED CURRANT–INFUSED WILD TURKEY RYE',
#  'DRY CHAMPAGNE',
#  'DRY VERMOUTH',
#  'EAGLE RARE 10-YEAR BOURBON',
#  'EARL GREY–INFUSED DOLIN BLANC VERMOUTH',
#  'EAST INDIA SOLERA SHERRY',
#  'EGG',
#  'EGG WHITE',
#  'EGG YOLK',
#  'EL DORADO 12-YEAR RUM',
#  'EL DORADO 15-YEAR RUM',
#  'EL DORADO 151 RUM',
#  'EL DORADO 3-YEAR RUM',
#  'EL DORADO HIGH-STRENGTH 151 RUM',
#  'EL TESORO AÑEJO TEQUILA',
#  'EL TESORO PLATINUM TEQUILA',
#  'EL TESORO REPOSADO TEQUILA',
#  'EL TESORO REPOSADO TEQUILA BEEFEATER LONDON DRY GIN COMPASS BOX ASYLA SCOTCH RITTENHOUSE 100 RYE OR HINE H COGNAC',
#  'ELIJAH CRAIG 12-YEAR BOURBON',
#  'ESPRESSO-INFUSED DEMERARA SYRUP',
#  'EVAN WILLIAMS SINGLE-BARREL BOURBON',
#  'FAMOUS GROUSE SCOTCH',
#  'FEE BROTHERS WHISKEY BARREL-AGED BITTERS',
#  'FERNET-BRANCA',
#  'FIG-INFUSED ELIJAH CRAIG BOURBON',
#  'FLOR DE CAÑA 7-YEAR RUM',
#  'FLOR DE CAÑA EXTRA-DRY WHITE RUM',
#  'FORDS GIN',
#  'FORD’S GIN',
#  'FORTALEZA REPOSADO TEQUILA',
#  'FRESH CURRY LEAVES',
#  'FRESH KAFFIR LIME LEAVES',
#  'FRESHLY GROUND NUTMEG',
#  'FUJI APPLE JUICE',
#  'FUJI APPLE SLICES',
#  'FUJI APPLE–INFUSED FAMOUS GROUSE SCOTCH',
#  'FULL SAIL SESSION BLACK LAGER',
#  'FUSION VERJUS BLANC',
#  'GABRIEL BOUDIER CURAÇAO',
#  'GALLIANO L’AUTENTICO',
#  'GALLIANO RISTRETTO',
#  'GINGER SYRUP',
#  'GOSLINGS BLACK SEAL RUM',
#  'GOSLING’S BLACK SEAL RUM',
#  'GRADE B MAPLE SYRUP',
#  'GRAN CLASSICO BITTER',
#  'GRAND MARNIER',
#  'GRANNY SMITH APPLE JUICE',
#  'GRANNY SMITH APPLE–INFUSED RHUM BARBANCOURT',
#  'GRAPEFRUIT COIN',
#  'GRAPEFRUIT JUICE',
#  'GRAPEFRUIT TWIST',
#  'GRAPEFRUIT TWISTS',
#  'GRAPEFRUIT-INFUSED PUNT E MES',
#  'GREEK YOGURT',
#  'GREEN CHARTREUSE',
#  'GREEN FLASH IPA',
#  'GREEN GRAPES',
#  'GRENADINE',
#  'GUILLON-PAINTURAUD COGNAC GRANDE CHAMPAGNE VSOP',
#  'HAYMAN’S OLD TOM GIN',
#  'HEAVY CREAM',
#  'HIBISCUS SYRUP',
#  'HIGH WEST SILVER OAT WHISKEY',
#  'HIGHLAND PARK 12-YEAR SCOTCH',
#  'HINE H COGNAC',
#  'HONEY NUT CHEERIO–INFUSED CREAM',
#  'HOUSE HORCHATA',
#  'HOUSE ORANGE BITTERS',
#  'HOUSE PEYCHAUD’S BITTERS',
#  'HOUSE SWEET VERMOUTH',
#  'JALAPEÑO-INFUSED SIEMBRA AZUL BLANCO TEQUILA',
#  'JALAPEÑO–INFUSED SIEMBRA AZUL BLANCO TEQUILA',
#  'KALANI RON DE COCO COCONUT LIQUEUR',
#  'KIRSCH',
#  'KNAPPOGUE CASTLE 12-YEAR IRISH WHISKEY',
#  'KOSHER SALT',
#  'KOVAL ROSE HIP LIQUEUR',
#  'KROGSTAD AQUAVIT',
#  'KRONAN SWEDISH PUNSCH',
#  'KUMQUAT CORDIAL',
#  'KÜMMEL LIQUEUR',
#  'LA CIGARRERA MANZANILLA SHERRY',
#  'LA DIABLADA PISCO',
#  'LA FAVORITE RHUM AGRICOLE AMBRE',
#  'LA FAVORITE RHUM AGRICOLE BLANC',
#  'LA GITANA MANZANILLA SHERRY',
#  'LAIRD’S BONDED APPLE BRANDY',
#  'LAPHROAIG 10-YEAR SCOTCH',
#  'LAPHROAIG 12-YEAR SCOTCH',
#  'LAPSANG SOUCHONG–INFUSED SIEMBRA AZUL BLANCO TEQUILA',
#  'LAVENDER-INFUSED BERNHEIM ORIGINAL WHEAT WHISKEY',
#  'LAZZARONI AMARETTO',
#  'LEMON COIN WITH A BIT OF PITH',
#  'LEMON CURD',
#  'LEMON HART 151 RUM',
#  'LEMON HART ORIGINAL RUM',
#  'LEMON JUICE',
#  'LEMON TWIST',
#  'LEMON TWISTS',
#  'LILLET BLANC',
#  'LILLET ROSÉ',
#  'LILLET ROUGE',
#  'LIME',
#  'LIME JUICE',
#  'LIME WEDGE',
#  'LIME WEDGES',
#  'LINIE AQUAVIT',
#  'LONG ORANGE TWISTS',
#  'LOS AMANTES JOVEN MEZCAL',
#  'LOS NAHUALES MEZCAL',
#  'LOUIS ROYER FORCE 53 COGNAC',
#  'LUSTAU AMONTILLADO SHEERY',
#  'LUSTAU AMONTILLADO SHERRY',
#  'LUSTAU EAST INDIA SOLERA SHERRY',
#  'LUSTAU LOS ARCOS AMONTILLADO SHERRY',
#  'LUSTAU MANZANILLA SHERRY',
#  'LUSTAU OLOROSO SHERRY',
#  'LUXARDO AMARO ABANO',
#  'LUXARDO MARASCHINO LIQUEUR',
#  'MACALLAN FINE OAK 10-YEAR SCOTCH',
#  'MACCHU PISCO',
#  'MACKESON STOUT',
#  'MANDARINE NAPOLÉON LIQUEUR',
#  'MAPLE SYRUP',
#  'MARASKA MARASCHINO LIQUEUR',
#  'MARIE BRIZARD APRICOT LIQUEUR',
#  'MARIE BRIZARD WHITE CRÈME DE CACAO',
#  'MARIE BRIZARD WHITE CRÈME DE MENTHE',
#  'MARTIN MILLER’S WESTBOURNE-STRENGTH GIN',
#  'MARTINI SWEET VERMOUTH',
#  'MASSENEZ CRÈME DE MÛRE BLACKBERRY LIQUEUR',
#  'MASSENEZ CRÈME DE PÊCHE PEACH LIQUEUR',
#  'MASSENEZ KIRSCH VIEUX CHERRY BRANDY',
#  'MATHILDE POIRE PEAR LIQUEUR',
#  'MERLET CRÈME DE FRAISE DES BOIS STRAWBERRY LIQUEUR',
#  'MINT LEAVES',
#  'MINT SPRIG',
#  'MINT SPRIGS',
#  'MORENITA CREAM SHERRY',
#  'MORRO BAY CHARDONNAY',
#  'MOUNT GAY ECLIPSE RUM',
#  'NEGRA MODELO BEER',
#  'NEISSON RHUM AGRICOLE BLANC',
#  'OCHO 2012 PLATA TEQUILA',
#  'OLD GRAND-DAD 114 BOURBON',
#  'OLD OVERHOLT RYE',
#  'OLD RAJ GIN',
#  'OLD WELLER ANTIQUE 107 BOURBON',
#  'ORANGE CRESCENT',
#  'ORANGE FLOWER WATER',
#  'ORANGE JUICE',
#  'ORANGE MARMALADE',
#  'ORANGE TWIST',
#  'ORANGE TWISTS',
#  'ORANGE WEDGES',
#  'ORANGE WHEEL',
#  'ORGEAT',
#  'OTIMA 10-YEAR TAWNY PORT',
#  'PAMPERO ANIVERSARIO RUM',
#  'PASQUET MARIE-FRAMBOISE',
#  'PASQUET PINEAU DES CHARENTES',
#  'PASSION FRUIT SYRUP',
#  'PECAN-INFUSED BUFFALO TRACE BOURBON',
#  'PECAN–INFUSED BUFFALO TRACE BOURBON',
#  'PENDENNIS MIX',
#  'PENNYROYAL-INFUSED HAYMAN’S OLD TOM GIN',
#  'PERRY’S TOT NAVY-STRENGTH GIN',
#  'PEYCHAUD’S BITTERS',
#  'PIERRE FERRAND 1840 COGNAC',
#  'PIERRE FERRAND AMBRE COGNAC',
#  'PIERRE FERRAND DRY CURAÇAO',
#  'PINEAPPLE JUICE',
#  'PINEAPPLE-INFUSED FLOR DE CAÑA EXTRA-DRY WHITE RUM',
#  'PLANTATION BARBADOS 5-YEAR RUM',
#  'PLYMOUTH BEEFEATER LONDON DRY OR TANQUERAY LONDON DRY GIN',
#  'PLYMOUTH GIN',
#  'PLYMOUTH GIN SCARLET IBIS RUM BERNHEIM WHEAT WHISKEY RITTENHOUSE 100 RYE LAIRD’S BONDED APPLE BRANDY OR HINE H COGNAC',
#  'PLYMOUTH GIN SCARLET IBIS RUM LAIRD’S BONDED APPLE BRANDY OR SIEMBRA AZUL BLANCO TEQUILA',
#  'PLYMOUTH SLOE GIN',
#  'POMEGRANATE MOLASSES',
#  'PUEBLO VIEJO AÑEJO TEQUILA',
#  'PUEBLO VIEJO REPOSADO TEQUILA',
#  'PUMPKIN BUTTER',
#  'PUMPKIN PUREE',
#  'PUNT E MES',
#  'QUEEN OF EARL TEA–INFUSED SIEMBRA AZUL REPOSADO TEQUILA',
#  'RAMAZZOTTI',
#  'RANSOM OLD TOM GIN',
#  'RASPBERRIES',
#  'RED BELL PEPPER PUREE',
#  'RED RIOJA WINE',
#  'RED THAI CHILE–INFUSED RITTENHOUSE RYE',
#  'REDBREAST 12-YEAR IRISH WHISKEY',
#  'REGANS’ ORANGE BITTERS',
#  'RHUM CLÉMENT CRÉOLE SHRUBB',
#  'RHUM JM 100-PROOF AGRICOLE BLANC',
#  'RIPE BARTLETT PEAR CUBED',
#  'RIPE PEACH SLICES',
#  'RITTENHOUSE 100 RYE',
#  'RITTENHOUSE 100 RYE LAIRD’S BONDED APPLE BRANDY SANTA TERESA 1796 RUM HINE H COGNAC OR FAMOUS GROUSE SCOTCH',
#  'RON DEL BARRILITO 3-STAR RUM',
#  'ROSE WATER',
#  'ROSE-INFUSED LILLET ROSÉ',
#  'ROTHMAN & WINTER APRICOT LIQUEUR',
#  'ROTHMAN & WINTER CHERRY LIQUEUR',
#  'ROTHMAN & WINTER CRÈME DE VIOLETTE',
#  'ROTHMAN & WINTER PEAR LIQUEUR',
#  'ROYAL COMBIER',
#  'ROYAL COMBIER LIQUEUR',
#  'RUBY PORT',
#  'RUSSELL’S RESERVE 10-YEAR BOURBON',
#  'RUSSELL’S RESERVE RYE',
#  'SAGE LEAVES',
#  'SAGE-INFUSED DOLIN BLANC VERMOUTH',
#  'SALERS GENTIEN APERITIF',
#  'SAN PELLEGRINO POMPELMO GRAPEFRUIT SODA',
#  'SANDEMAN RAINWATER MADEIRA',
#  'SANDEMAN RUBY PORT',
#  'SANTA TERESA 1796 RUM',
#  'SANTA TERESA ORANGE LIQUEUR',
#  'SANTA TERESA RUM',
#  'SAUVIGNON BLANC',
#  'SAZERAC 6-YEAR RYE',
#  'SCARLET GLOW SYRUP',
#  'SCARLET GLOW TEA–INFUSED MACCHU PISCO',
#  'SCARLET IBIS RUM',
#  'SCRAPPY’S LAVENDER BITTERS',
#  'SIEMBRA AZUL AÑEJO TEQUILA',
#  'SIEMBRA AZUL BLANCO TEQUILA',
#  'SIEMBRA AZUL REPOSADO TEQUILA',
#  'SIETE LEGUAS BLANCO TEQUILA',
#  'SIETE LEGUAS REPOSADO TEQUILA',
#  'SIMPLE SYRUP',
#  'SLOE GIN',
#  'SMALL FRESH KAFFIR LIME LEAF',
#  'SMALL NECTARINE SLICES',
#  'SMALL RIPE ANJOU PEAR SLICES',
#  'SMITH & CROSS RUM',
#  'SMOKED SALT',
#  'SOLERNO BLOOD ORANGE LIQUEUR',
#  'SOMBRA MEZCAL',
#  'SPARKLING ROSÉ',
#  'SPICED PEAR–INFUSED SIEMBRA AZUL BLANCO TEQUILA',
#  'SPICY SUGAR AND SALT RIM',
#  'SPLASH OF CLUB SODA',
#  'SPRINGBANK 10-YEAR SCOTCH',
#  'ST-GERMAIN',
#  'ST. ELIZABETH ALLSPICE DRAM',
#  'ST. GEORGE ABSINTHE',
#  'ST. JAMES ROYAL AMBRE RHUM AGRICOLE',
#  'STAGG BOURBON',
#  'STRAWBERRY',
#  'STRAWBERRY- AND PINEAPPLE-INFUSED MACCHU PISCO',
#  'STRAWBERRY-BALSAMIC GASTRIQUE',
#  'STREGA',
#  'SUGAR SNAP PEA–INFUSED PLYMOUTH GIN',
#  'SUMMER ROYALE TEA–INFUSED FLOR DE CAÑA WHITE RUM',
#  'SUNTORY HAKASHU 12-YEAR WHISKY',
#  'SUNTORY HAKUSHU 12-YEAR WHISKEY',
#  'SUPERFINE SUGAR',
#  'SUZE SAVEUR D’AUTREFOIS LIQUEUR',
#  'SZECHUAN PEPPERCORN–INFUSED PLYMOUTH GIN',
#  'TABASCO CHIPOTLE SAUCE',
#  'TANGERINE PEELED',
#  'TANQUERAY LONDON DRY GIN',
#  'TANQUERAY NO. TEN GIN',
#  'TAPATIO 110 BLANCO TEQUILA',
#  'TARIQUET VS CLASSIQUE BAS-ARMAGNAC',
#  'TARRAGON AND AGAVE NECTAR GASTRIQUE',
#  'TEMPLETON RYE',
#  'THAI BASIL LEAVES',
#  'THIN CUCUMBER WHEELS',
#  'TOASTED FENNEL SALT RIM',
#  'TOBY’S LIME CORDIAL',
#  'TOBY’S SOUR CHERRY SHRUB',
#  'VAN OOSTEN BATAVIA ARRACK',
#  'VANILLA SYRUP',
#  'VELVET FALERNUM',
#  'VIEUX PONTARLIER ABSINTHE',
#  'WAQAR PISCO',
#  'WATERMELON JUICE',
#  'WATERMELON-INFUSED DOLIN DRY VERMOUTH',
#  'WHITE SUGAR CUBE',
#  'WHITE SUGAR CUBES',
#  'WHOLE EGG',
#  'WILD TURKEY 101 RYE',
#  'WILLIAMS & HUMBERT DRY SACK MEDIUM SHERRY',
#  'WOODFORD RESERVE BOURBON',
#  'YAMAZAKI 12-YEAR WHISKEY',
#  'YELLOW CHARTREUSE',
#  'YELLOW CHARTREUSE (SCANT)',
#  'ZACAPA 23-YEAR RUM',
#  'ZIRBENZ STONE PINE LIQUEUR',
#  'ZOCO PACHARÁN NAVARRO LIQUEUR',
#  'ZOMBIE MIX',
#  'ÉLIXIR COMBIER'}

# %%
name_regex = '(.*)\((.*)\)'
m = re.match(name_regex, test_name)

# %%
m.group(2)
# Out:
# 'BLACKBERRY'

# %%
s = ' asdf asdf '

# %%
s.strip()
# Out:
# 'asdf asdf'
